# %% [raw]
# We are using miles peer gallon dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("mpg")

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# We doot need the name column here
df.drop("name",axis=1, inplace=True)

# %%
# Finding the number of NullValues 
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
# Since we have not done any outlier treatemnt so we have to replae the ull Values in HorePower Column with median value 
df["horsepower"] = df["horsepower"].fillna(df.horsepower.median())

# determine the value of horsepower Median 
df.horsepower.median()
# Out:
# 93.5

# %%
df["horsepower"]
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
# Again Finding the number of NullValues 
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
# Determinng the data Type of the columns in the dataset
df.info()
# We need to change the datatype of the object type to numerical values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
# # So we need to change the values in the origin column forom object type to integer type 
# # Lets first determine the diffrent ypes of categiors of values in the origin columns
df["origin"].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
df["origin"] = df["origin"].map({"usa":1,"japan":2,"europe":3})
# # # Converting the datatype of the origin columns into int64
df["origin"] = df["origin"].astype(int)

# %%
df["origin"].value_counts()
# Out:
# origin
# 1    249
# 2     79
# 3     70
# Name: count, dtype: int64

# %%
df.info() # Now we can see all the features have the datatype intgere or float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int32
# dtypes: float64(4), int32(1), int64(3)
# memory usage: 23.4 KB

# %%
# You need to seperate the X and y 
# Target variable (y)
y = df['mpg']

# Feature variables (X) - all columns except 'mpg'
X = df.drop('mpg', axis=1)

# %%
from sklearn.model_selection import train_test_split

# Assuming X and y are already defined as features and target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# This will split 80% of the data into training and 20% into testing

# %%
from sklearn.linear_model import LinearRegression

# %%
# Initialize the Linear Regression model
regression_model = LinearRegression()

# %%
# Fit the model using the training data
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
for index, column_name in enumerate(X_train.columns):
    print(column_name,regression_model.coef_[index])
# Out:
# cylinders -0.31761423027992836
# displacement 0.026237482599078918
# horsepower -0.018270764913124512
# weight -0.007487750398361906
# acceleration 0.05040673461971436
# model_year 0.8470951427061368
# origin 1.5190958387975058

# %% [raw]
# Coefficinets are relatively smaller,  if one independent variale changes slightly ther will be no much ifrenec ein the prediction
# This means all features are equally important so it is caled smoother model

# %%
# This will give you the R-squared score for your linear regression model, specifically for the test set

from sklearn.metrics import r2_score

# Predicting on the test data
y_pred_linear = regression_model.predict(X_test)

# Calculate the R-squared score for the test data
r2_linear = r2_score(y_test, y_pred_linear)

print(f"R-squared score for the test set: {r2_linear}")
# Out:
# R-squared score for the test set: 0.8348001123742286

# %%
from sklearn.linear_model import Ridge

# %%
# Initialize the Ridge Regression model
ridge_regression_model = Ridge(alpha=1.0)

# %%
# Fit the Ridge model using the training data
ridge_regression_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
for index, column_name in enumerate(X_train.columns):
    print(column_name,ridge_regression_model.coef_[index])
# So here we can see there is not much change in the coefficients in regression model and ridge_regression model
# This means that there is no much learning by the model after L2 regualrization
# Out:
# cylinders -0.3115979445994963
# displacement 0.025997977253605586
# horsepower -0.018196431282461345
# weight -0.007483542125803001
# acceleration 0.05003261423029701
# model_year 0.8462126659579855
# origin 1.5028233365628834

# %%
# Predicting on the test data
y_pred_ridge = ridge_regression_model.predict(X_test)

# Calculate the R-squared score for the test data
r2_ridge = r2_score(y_test, y_pred_ridge)

print(f"R-squared score for the test set: {r2_ridge}")
# We dont see much variation in R2 score of ridge regression than Linear regression
# Out:
# R-squared score for the test set: 0.8348814925912453

# %%
from sklearn.linear_model import Lasso

# %%
# Initialize the Lasso Regression model
lasso_regression_model = Lasso(alpha=0.5)  # Adjust the alpha value if needed

# %%
# Fit the Lasso model using the training data
lasso_regression_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.5)

# %%
# Coefficients for Lasso Regression
print("Lasso Regression Coefficients:")
for index, column_name in enumerate(X_train.columns):
    print(column_name, lasso_regression_model.coef_[index])
# Out:
# Lasso Regression Coefficients:
# cylinders -0.0
# displacement 0.006208198888300369
# horsepower -0.01105838298716959
# weight -0.006982673168023089
# acceleration 0.0
# model_year 0.744654952003819
# origin 0.0

# %%
# Predicting on the test data using Lasso Regression
y_pred_lasso = lasso_regression_model.predict(X_test)

# %%
# Calculate the R-squared score for the test data using Lasso Regression
r2_lasso = r2_score(y_test, y_pred_lasso)

# Print the R-squared score
print(f"R-squared score for the test set (Lasso Regression): {r2_lasso}")

# Now we an see that the r2scoe with lasso regularization has redued from 83 to 82 as comaprred to Linear regresson r2 score 
# Tha Means lassso has eliminated soe of the unimportant features
# Out:
# R-squared score for the test set (Lasso Regression): 0.8277934716635555

# %%
from sklearn.linear_model import ElasticNet

# %%
# Initialize the Elastic Net Regression model
elastic_net_model = ElasticNet(alpha=1.0, l1_ratio=0.5)  # Adjust alpha and l1_ratio if needed

# %%
# Fit the Elastic Net model using the training data
elastic_net_model.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
# Coefficients for Elastic Net Regression
print("Elastic Net Regression Coefficients:")
for index, column_name in enumerate(X_train.columns):
    print(column_name, elastic_net_model.coef_[index])
# Out:
# Elastic Net Regression Coefficients:
# cylinders -0.0
# displacement 0.0058888699536675465
# horsepower -0.012403874933570107
# weight -0.00693455051625763
# acceleration 0.0
# model_year 0.7133150744603873
# origin 0.0

# %%
# Predicting on the test data using Elastic Net Regression
y_pred_elastic_net = elastic_net_model.predict(X_test)

# %%
# Calculate the R-squared score for the test data using Elastic Net Regression
r2_elastic_net = r2_score(y_test, y_pred_elastic_net)

# Print the R-squared score
print(f"R-squared score for the test set (Elastic Net Regression): {r2_elastic_net}")
# Out:
# R-squared score for the test set (Elastic Net Regression): 0.8284840073256804

# %%
from sklearn.linear_model import LassoCV

# Initialize the LassoCV model
lasso_cv_model = LassoCV(cv=5)  # You can adjust the alpha values and cv folds if needed

# Fit the LassoCV model using the training data
lasso_cv_model.fit(X_train, y_train)

# Predicting on the test data using LassoCV
y_pred_lasso_cv = lasso_cv_model.predict(X_test)

# Calculate the R-squared score for the test data using LassoCV
r2_lasso_cv = r2_score(y_test, y_pred_lasso_cv)

# Print the R-squared score
print(f"R-squared score for the test set (LassoCV Regression): {r2_lasso_cv}")
# Out:
# R-squared score for the test set (LassoCV Regression): 0.808280598384475

# %%
from sklearn.linear_model import RidgeCV
from sklearn.metrics import r2_score

# Initialize the RidgeCV model
ridge_cv_model = RidgeCV(cv=5)  # You can adjust the alpha values and cv folds if needed

# Fit the RidgeCV model using the training data
ridge_cv_model.fit(X_train, y_train)

# Predicting on the test data using RidgeCV
y_pred_ridge_cv = ridge_cv_model.predict(X_test)

# Calculate the R-squared score for the test data using RidgeCV
r2_ridge_cv = r2_score(y_test, y_pred_ridge_cv)

# Print the R-squared score
print(f"R-squared score for the test set (RidgeCV Regression): {r2_ridge_cv}")

# # Optionally, you can print the best alpha value
# best_alpha_ridge = ridge_cv_model.alpha_
# print(f"Best alpha value found: {best_alpha_ridge}")

# # Coefficients for RidgeCV Regression
# print("RidgeCV Regression Coefficients:")
# for index, column_name in enumerate(X_train.columns):
#     print(column_name, ridge_cv_model.coef_[index])
# Out:
# R-squared score for the test set (RidgeCV Regression): 0.8354145247502054

# %%
ridge_cv_model.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_values': False}

# %%
lasso_cv_model.get_params()
# Out:
# {'alphas': None,
#  'copy_X': True,
#  'cv': 5,
#  'eps': 0.001,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'n_alphas': 100,
#  'n_jobs': None,
#  'positive': False,
#  'precompute': 'auto',
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'verbose': False}

# %%
from sklearn.linear_model import ElasticNetCV
from sklearn.metrics import r2_score

# Initialize the ElasticNetCV model
elastic_net_cv_model = ElasticNetCV(cv=5)  # You can adjust the alpha values and cv folds if needed

# Fit the ElasticNetCV model using the training data
elastic_net_cv_model.fit(X_train, y_train)

# Get the best alpha and l1_ratio found by ElasticNetCV
best_alpha = elastic_net_cv_model.alpha_
best_l1_ratio = elastic_net_cv_model.l1_ratio_
print(f"Best alpha value found: {best_alpha}")
print(f"Best l1_ratio value found: {best_l1_ratio}")

# Get the coefficients of the ElasticNetCV model
coefficients = elastic_net_cv_model.coef_
print("ElasticNetCV Regression Coefficients:")
for index, column_name in enumerate(X_train.columns):
    print(f"{column_name}: {coefficients[index]}")

# Predicting on the test data using ElasticNetCV
y_pred_elastic_net_cv = elastic_net_cv_model.predict(X_test)

# Calculate the R-squared score for the test data using ElasticNetCV
r2_elastic_net_cv = r2_score(y_test, y_pred_elastic_net_cv)

# Print the R-squared score
print(f"R-squared score for the test set (ElasticNetCV Regression): {r2_elastic_net_cv}")

# Optionally, you can also get the list of parameters used in ElasticNetCV
print("ElasticNetCV parameters:")
print(f"Alpha values tested: {elastic_net_cv_model.alphas_}")
